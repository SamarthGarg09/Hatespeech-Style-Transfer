# %%
corpus = [
    "This is the Hugging Face Course.",
    "This chapter is about tokenization.",
    "This section shows several tokenizer algorithms.",
    "Hopefully, you will be able to understand how they are trained and generate tokens.",
]

# %%
from transformers import AutoTokenizer

tokenizer = AutoTokenizer.from_pretrained("gpt2")

# %%
from collections import defaultdict

word_freqs = defaultdict(int)
for text in corpus:
    word_offset_list = tokenizer.backend_tokenizer.pre_tokenizer.pre_tokenize_str(text)
    words = [word for word, offset in word_offset_list]
    for word in words:
        word_freqs[word] += 1
print(word_freqs)
# Out:
# defaultdict(<class 'int'>, {'This': 3, 'Ġis': 2, 'Ġthe': 1, 'ĠHugging': 1, 'ĠFace': 1, 'ĠCourse': 1, '.': 4, 'Ġchapter': 1, 'Ġabout': 1, 'Ġtokenization': 1, 'Ġsection': 1, 'Ġshows': 1, 'Ġseveral': 1, 'Ġtokenizer': 1, 'Ġalgorithms': 1, 'Hopefully': 1, ',': 1, 'Ġyou': 1, 'Ġwill': 1, 'Ġbe': 1, 'Ġable': 1, 'Ġto': 1, 'Ġunderstand': 1, 'Ġhow': 1, 'Ġthey': 1, 'Ġare': 1, 'Ġtrained': 1, 'Ġand': 1, 'Ġgenerate': 1, 'Ġtokens': 1})

# %%
base_vocab = []
for word, freqs in word_freqs.items():
    for char in word:
        if char not in base_vocab:
            base_vocab.append(char)

base_vocab.sort()

# %%
vocab = ["<|startoftext|>", "<|endoftext|>"] + base_vocab.copy()
splits = {word: [c for c in word] for word in word_freqs.keys()}

def compute_pair_freqs(splits):
    pairs = defaultdict(int)
    for word, split in splits.items():
        if len(word)==1:
            continue
        else:
            for i in range(len(split)-1):
                pairs[(split[i], split[i+1])] += 1
    return pairs

pair_freqs = compute_pair_freqs(splits)

# %%
max_freq = 0
best_pair = ""
for pair, freq in pair_freqs.items():
    if freq > max_freq:
        best_pair = pair[0]+pair[1]
        max_freq = freq
best_pair, max_freq
# Out:
# ('Ġt', 7)

# %%
vocab.append("Ġt")

# %%
def merge_pair(a, b, split):
    for word in word_freqs:
        split = splits[word]
        if len(split) == 1:
            continue
        i=0
        while i<len(split)-1:
            if split[i] == a and split[i+1] == b:
                split = split[:i] + [a+b] + split[i+2:]
            else:
                i += 1
        splits[word] = split
    return splits

splits = merge_pair("Ġ", "t", splits)
print(splits["Ġtrained"])
# Out:
# ['Ġt', 'r', 'a', 'i', 'n', 'e', 'd']

# %%
path = "/Data/deeksha/disha/code_p/transformers/train.en"
with open(path, "r") as f:
    corpus = f.readlines()
corpus = [line.strip() for line in corpus]
corpus[:5]
# Out:
# ['Two young, White males are outside near many bushes.',
#  'Several men in hard hats are operating a giant pulley system.',
#  'A little girl climbing into a wooden playhouse.',
#  'A man in a blue shirt is standing on a ladder cleaning a window.',
#  'Two men are at the stove preparing food.']

# %%
from transformers import AutoTokenizer
from collections import defaultdict


vocab_size = 10000
merges = defaultdict(list)
tokenizer = AutoTokenizer.from_pretrained("gpt2")

word_freqs = defaultdict(int)
for text in corpus:
    word_offset_list = tokenizer.backend_tokenizer.pre_tokenizer.pre_tokenize_str(text)
    words = [word for word, offset in word_offset_list]
    for word in words:
        word_freqs[word] += 1
print(word_freqs)

base_vocab = []
for word, freqs in word_freqs.items():
    for char in word:
        if char not in base_vocab:
            base_vocab.append(char)

base_vocab.sort()

vocab = ["<|startoftext|>", "<|endoftext|>"] + base_vocab.copy()
splits = {word: [c for c in word] for word in word_freqs.keys()}

def compute_pair_freqs(splits):
    pairs = defaultdict(int)
    for word, split in splits.items():
        if len(word)==1:
            continue
        else:
            for i in range(len(split)-1):
                pairs[(split[i], split[i+1])] += 1
    return pairs

pair_freqs = compute_pair_freqs(splits)

def merge_pair(a, b, split):
    for word in word_freqs:
        split = splits[word]
        if len(split) == 1:
            continue
        i=0
        while i<len(split)-1:
            if split[i] == a and split[i+1] == b:
                split = split[:i] + [a+b] + split[i+2:]
            else:
                i += 1
        splits[word] = split
    return splits

while len(vocab) < vocab_size:
    pair_freqs = compute_pair_freqs(splits)
    best_pair = ""
    max_freq = 0
    for pair, freq in pair_freqs.items():
        if max_freq is not None and freq > max_freq:
            best_pair = (pair[0], pair[1])
            max_freq = freq
    splits = merge_pair(best_pair[0], best_pair[1], splits)
    merges[best_pair] = best_pair[0] + best_pair[1]
    best_pair = best_pair[0] + best_pair[1]
    vocab.append(best_pair)
# Out:
# defaultdict(<class 'int'>, {'Two': 3115, 'Ġyoung': 2074, ',': 3958, 'ĠWhite': 5, 'Ġmales': 39, 'Ġare': 3715, 'Ġoutside': 870, 'Ġnear': 569, 'Ġmany': 120, 'Ġbushes': 19, '.': 27601, 'Several': 280, 'Ġmen': 1612, 'Ġin': 14842, 'Ġhard': 120, 'Ġhats': 146, 'Ġoperating': 22, 'Ġa': 31705, 'Ġgiant': 43, 'Ġpulley': 3, 'Ġsystem': 6, 'A': 17458, 'Ġlittle': 843, 'Ġgirl': 1666, 'Ġclimbing': 191, 'Ġinto': 711, 'Ġwooden': 174, 'Ġplayhouse': 3, 'Ġman': 7355, 'Ġblue': 1868, 'Ġshirt': 2126, 'Ġis': 7524, 'Ġstanding': 1612, 'Ġon': 8017, 'Ġladder': 60, 'Ġcleaning': 60, 'Ġwindow': 183, 'Ġat': 2908, 'Ġthe': 9922, 'Ġstove': 23, 'Ġpreparing': 104, 'Ġfood': 352, 'Ġgreen': 914, 'Ġholds': 322, 'Ġguitar': 365, 'Ġwhile': 1932, 'Ġother': 660, 'Ġobserves': 13, 'Ġhis': 1969, 'Ġsmiling': 344, 'Ġstuffed': 32, 'Ġlion': 7, 'Ġtrendy': 2, 'Ġtalking': 382, 'Ġher': 1263, 'Ġcellphone': 144, 'Ġgliding': 5, 'Ġslowly': 3, 'Ġdown': 1386, 'Ġstreet': 1432, 'Ġwoman': 3816, 'Ġwith': 6175, 'Ġlarge': 825, 'Ġpurse': 52, 'Ġwalking': 1376, 'Ġby': 1044, 'Ġgate': 27, 'Boys': 12, 'Ġdancing': 183, 'Ġpoles': 27, 'Ġmiddle': 256, 'Ġof': 6863, 'Ġnight': 137, 'Ġballet': 11, 'Ġclass': 53, 'Ġfive': 44, 'Ġgirls': 424, 'Ġjumping': 491, 'Ġsequence': 2, 'Four': 314, 'Ġguys': 101, 'Ġthree': 202, 'Ġwearing': 2618, 'Ġone': 913, 'Ġnot': 29, 'Ġtop': 411, 'Ġstaircase': 30, 'Ġblack': 1985, 'Ġdog': 1650, 'Ġand': 7376, 'Ġspotted': 13, 'Ġfighting': 50, 'Ġneon': 22, 'Ġorange': 519, 'Ġuniform': 192, 'Ġdriving': 68, 'Ġtractor': 25, 'Ġwomen': 918, 'Ġwait': 52, 'Ġcity': 432, 'Ġlady': 362, 'Ġglasses': 306, 'Ġsprinkling': 3, 'Ġpowdered': 2, 'Ġsugar': 1, 'Ġbundt': 1, 'Ġcake': 56, 'Ġsitting': 1740, 'Ġfront': 1271, 'Ġpainted': 64, 'Ġrainbow': 15, 'Ġlays': 31, 'Ġbench': 310, 'Ġto': 3124, 'Ġwhich': 83, 'Ġwhite': 2211, 'Ġalso': 20, 'Ġtied': 16, 'Five': 127, 'Ġpeople': 2546, 'Ġcircle': 31, 'Ġinstruments': 86, 'Ġbunch': 60, 'Ġelderly': 180, 'Ġplay': 363, 'Ġtheir': 723, 'Ġclarinets': 1, 'Ġtogether': 361, 'Ġas': 845, 'Ġthey': 170, 'Ġread': 19, 'Ġoff': 404, 'Ġsheet': 28, 'Ġmusic': 118, 'Ġstructure': 66, 'Ġhas': 339, 'Ġbroken': 16, 'Ġlaying': 149, 'Ġroadway': 4, 'Ġcrowd': 507, 'Ġstand': 447, 'Ġentrance': 19, 'ĠMetro': 1, 'Ġstation': 68, 'Ġgetting': 167, 'Ġtattoo': 37, 'Ġback': 243, 'Ġchildren': 668, 'Ġsit': 301, 'Ġsmall': 638, 'Ġseesaw': 5, 'Ġsand': 213, 'Ġreflective': 17, 'Ġvest': 118, 'Ġhat': 720, 'Ġflag': 84, 'Ġroad': 311, 'Ġperson': 688, 'Ġdressed': 634, 'Ġcoat': 228, 'Ġbusy': 160, 'Ġsidewalk': 532, 'Ġstudying': 13, 'Ġpainting': 122, 'Ġscene': 59, 'Ġpants': 306, 'The': 1025, 'Ġchild': 868, 'Ġclimbs': 52, 'Ġred': 1741, 'Ġropes': 21, 'Ġplayground': 83, 'You': 4, 'Ġknow': 4, 'Ġi': 4, 'Ġam': 4, 'Ġlooking': 880, 'Ġlike': 96, 'ĠJustin': 1, 'ĠBieber': 1, 'Ġyellow': 775, 'Ġjacket': 564, 'Ġgazing': 9, 'Ġsomething': 379, 'Ġurinal': 2, 'Ġcoffee': 63, 'Ġcup': 66, 'Ġmulticolored': 41, 'Ġsky': 75, 'Ġbackground': 460, 'Ġold': 276, 'Ġhaving': 172, 'Ġbeer': 75, 'Ġalone': 44, 'Ġtrained': 4, 'Ġpolice': 95, 'Ġsits': 492, 'Ġnext': 663, 'Ġhandler': 2, 'Ġvan': 38, 'Ġriding': 583, 'Ġbike': 443, 'Ġsnowy': 120, 'Ġuniformly': 1, 'Ġshirts': 158, 'Ġtie': 53, 'Ġslacks': 7, 'Ġconverse': 13, 'Ġan': 1943, 'Ġopen': 132, 'Ġbackwards': 24, 'Ġworks': 76, 'Ġmachinery': 20, 'Ġworking': 359, 'Ġfactory': 13, 'Ġsetting': 92, 'Ġpacking': 4, 'Ġjars': 3, 'Ġcandles': 16, 'Ġboxes': 30, 'Asian': 45, 'Ġsweeping': 37, 'Ġwalkway': 49, 'Ġleans': 45, 'Ġcar': 324, 'Ġtalk': 48, 'Ġdriver': 28, 'Ġbicycle': 287, 'Ġlooks': 417, 'Ġtoddlers': 10, 'Ġgrass': 468, 'People': 573, 'Ġwatching': 261, 'Ġweird': 4, 'Ġvehicle': 64, 'Ġplaza': 23, 'Ġwalks': 369, 'Ġsilver': 54, 'Ġbeautiful': 99, 'Ġbride': 51, 'Ġnew': 38, 'Ġhusband': 6, 'Ġboy': 1627, 'Ġplaying': 1583, 'ĠGameCube': 1, 'ĠMcDonald': 6, "'s": 444, 'Ġshakes': 14, 'Ġedge': 71, 'Ġbeach': 518, 'Ġball': 722, 'Ġgroup': 1491, 'Ġbarbecue': 20, 'Ġpark': 384, 'Ġsunglasses': 206, 'Ġputs': 30, 'Ġarm': 94, 'Ġaround': 561, 'Ġblouse': 31, 'Ġballoon': 58, 'Ġeating': 236, 'Ġoutdoors': 114, 'Ġpicnic': 32, 'Ġtables': 46, 'Ġjump': 154, 'Ġkicking': 6 ...

# %%
merges
# Out:
# defaultdict(list,
#             {('i', 'n'): 'in',
#              ('e', 'r'): 'er',
#              ('Ġ', 's'): 'Ġs',
#              ('in', 'g'): 'ing',
#              ('e', 's'): 'es',
#              ('Ġ', 'c'): 'Ġc',
#              ('e', 'd'): 'ed',
#              ('a', 'r'): 'ar',
#              ('a', 'n'): 'an',
#              ('Ġ', 'p'): 'Ġp',
#              ('o', 'n'): 'on',
#              ('a', 't'): 'at',
#              ('Ġ', 'b'): 'Ġb',
#              ('e', 'n'): 'en',
#              ('o', 'r'): 'or',
#              ('Ġ', 't'): 'Ġt',
#              ('a', 'l'): 'al',
#              ('l', 'e'): 'le',
#              ('Ġ', 'f'): 'Ġf',
#              ('r', 'e'): 're',
#              ('Ġ', 'd'): 'Ġd',
#              ('Ġ', 'm'): 'Ġm',
#              ('r', 'o'): 'ro',
#              ('s', 't'): 'st',
#              ('i', 'c'): 'ic',
#              ('e', 'l'): 'el',
#              ('Ġ', 'h'): 'Ġh',
#              ('a', 'c'): 'ac',
#              ('i', 't'): 'it',
#              ('er', 's'): 'ers',
#              ('u', 'n'): 'un',
#              ('Ġ', 'w'): 'Ġw',
#              ('a', 's'): 'as',
#              ('i', 'l'): 'il',
#              ('a', 'd'): 'ad',
#              ('Ġ', 'g'): 'Ġg',
#              ('u', 'r'): 'ur',
#              ('l', 'o'): 'lo',
#              ('r', 'a'): 'ra',
#              ('r', 'i'): 'ri',
#              ('o', 'l'): 'ol',
#              ('e', 't'): 'et',
#              ('Ġs', 't'): 'Ġst',
#              ('en', 't'): 'ent',
#              ('c', 'h'): 'ch',
#              ('i', 's'): 'is',
#              ('o', 'm'): 'om',
#              ('i', 'on'): 'ion',
#              ('u', 's'): 'us',
#              ('a', 'm'): 'am',
#              ('l', 'y'): 'ly',
#              ('Ġ', 'e'): 'Ġe',
#              ('i', 'r'): 'ir',
#              ('o', 't'): 'ot',
#              ('u', 't'): 'ut',
#              ('Ġ', 'l'): 'Ġl',
#              ('i', 'g'): 'ig',
#              ('i', 'd'): 'id',
#              ('u', 'l'): 'ul',
#              ('an', 'd'): 'and',
#              ('o', 'w'): 'ow',
#              ('a', 'p'): 'ap',
#              ('a', 'g'): 'ag',
#              ('o', 'p'): 'op',
#              ('Ġ', 're'): 'Ġre',
#              ('Ġs', 'h'): 'Ġsh',
#              ('u', 'm'): 'um',
#              ('e', 'c'): 'ec',
#              ('ar', 'd'): 'ard',
#              ('a', 'y'): 'ay',
#              ('Ġc', 'h'): 'Ġch',
#              ('t', 's'): 'ts',
#              ('Ġ', 'in'): 'Ġin',
#              ('Ġ', 'S'): 'ĠS',
#              ('Ġs', 'p'): 'Ġsp',
#              ('Ġ', 'v'): 'Ġv',
#              ('es', 's'): 'ess',
#              ('k', 's'): 'ks',
#              ('Ġ', 'n'): 'Ġn',
#              ('i', 'm'): 'im',
#              ('o', 'o'): 'oo',
#              ('Ġ', 'r'): 'Ġr',
#              ('a', 'k'): 'ak',
#              ('i', 'st'): 'ist',
#              ('Ġ', 'o'): 'Ġo',
#              ('i', 'v'): 'iv',
#              ('Ġc', 'on'): 'Ġcon',
#              ('t', 'er'): 'ter',
#              ('Ġ', 'k'): 'Ġk',
#              ('a', 'b'): 'ab',
#              ('Ġ', 'C'): 'ĠC',
#              ('e', 'm'): 'em',
#              ('es', 't'): 'est',
#              ('i', 'p'): 'ip',
#              ('ac', 'k'): 'ack',
#              ('a', 'in'): 'ain',
#              ('al', 'l'): 'all',
#              ('t', 'ing'): 'ting',
#              ('v', 'er'): 'ver',
#              ('c', 'k'): 'ck',
#              ('a', 'st'): 'ast',
#              ('l', 'ing'): 'ling',
#              ('Ġ', 'M'): 'ĠM',
#              ('ig', 'h'): 'igh',
#              ('f', 'f'): 'ff',
#              ('q', 'u'): 'qu',
#              ('u', 'p'): 'up',
#              ('l', 'es'): 'les',
#              ('u', 'g'): 'ug',
#              ('Ġ', 'ro'): 'Ġro',
#              ('Ġ', 'B'): 'ĠB',
#              ('d', 's'): 'ds',
#              ('e', 'w'): 'ew',
#              ('Ġe', 'x'): 'Ġex',
#              ('as', 's'): 'ass',
#              ('c', 'e'): 'ce',
#              ('o', 's'): 'os',
#              ('b', 'o'): 'bo',
#              ('Ġs', 'c'): 'Ġsc',
#              ('Ġ', 'a'): 'Ġa',
#              ('Ġ', 'j'): 'Ġj',
#              ('Ġc', 'o'): 'Ġco',
#              ('at', 'e'): 'ate',
#              ('an', 't'): 'ant',
#              ('h', 'e'): 'he',
#              ('Ġ', 'A'): 'ĠA',
#              ('e', 'e'): 'ee',
#              ('ar', 't'): 'art',
#              ('at', 'ion'): 'ation',
#              ('u', 'd'): 'ud',
#              ('is', 'h'): 'ish',
#              ('l', 'ed'): 'led',
#              ('Ġ', 'un'): 'Ġun',
#              ('Ġ', 'lo'): 'Ġlo',
#              ('o', 'us'): 'ous',
#              ('t', 'ed'): 'ted',
#              ('Ġ', 'le'): 'Ġle',
#              ('in', 'e'): 'ine',
#              ('Ġ', 'T'): 'ĠT',
#              ('o', 'un'): 'oun',
#              ('d', 'er'): 'der',
#              ('k', 'ing'): 'king',
#              ('i', 'f'): 'if',
#              ('il', 'l'): 'ill',
#              ('Ġ', 'P'): 'ĠP',
#              ('Ġp', 'ro'): 'Ġpro',
#              ('an', 'g'): 'ang',
#              ('an', 's'): 'ans',
#              ('u', 'b'): 'ub',
#              ('i', 'es'): 'ies',
#              ('h', 'er'): 'her',
#              ('i', 'e'): 'ie',
#              ('Ġs', 'w'): 'Ġsw',
#              ('lo', 'w'): 'low',
#              ('a', 'v'): 'av',
#              ('or', 's'): 'ors',
#              ('u', 'st'): 'ust',
#              ('d', 'ing'): 'ding',
#              ('Ġc', 'om'): 'Ġcom',
#              ('c', 't'): 'ct',
#              ('Ġf', 'l'): 'Ġfl',
#              ('o', 'd'): 'od',
#              ('Ġ', 'D'): 'ĠD',
#              ('Ġs', 'n'): 'Ġsn',
#              ('ac', 'h'): 'ach',
#              ('as', 'h'): 'ash',
#              ('i', 'z'): 'iz',
#              ('Ġp', 'l'): 'Ġpl',
#              ('p', 'ing'): 'ping',
#              ('a', 'ir'): 'air',
#              ('r', 'y'): 'ry',
#              ('e', 'ar'): 'ear',
#              ('ic', 'k'): 'ick',
#              ('Ġ', 'G'): 'ĠG',
#              ('e', 'at'): 'eat',
#              ('Ġ', 'H'): 'ĠH',
#              ('Ġs', 'k'): 'Ġsk',
#              ('Ġ', 'ar'): 'Ġar',
#              ('Ġc', 'l'): 'Ġcl',
#              ('Ġt', 'h'): 'Ġth',
#              ('ap', 'p'): 'app',
#              ('a', 'il'): 'ail',
#              ('u', 're'): 'ure',
#              ('or', 't'): 'ort',
#              ('k', 'e'): 'ke',
#              ('ag', 'e'): 'age',
#              ('ra', 'p'): 'rap',
#              ('en', 's'): 'ens',
#              ('igh', 't'): 'ight',
#              ('bo', 'ard'): 'board',
#              ('Ġ', 'F'): 'ĠF',
#              ('on', 'e'): 'one',
#              ('Ġs', 'e'): 'Ġse',
#              ('o', 'g'): 'og',
#              ('ro', 'w'): 'row',
#              ('r', 'ess'): 'ress',
#              ('Ġh', 'e'): 'Ġhe',
#              ('Ġ', 'R'): 'ĠR',
#              ('Ġb', 'e'): 'Ġbe',
#              ('id', 'e'): 'ide',
#              ('Ġt', 'r'): 'Ġtr',
#              ('ac', 't'): 'act',
#              ('at', 't'): 'att',
#              ('ec', 't'): 'ect',
#              ('o', 'ut'): 'out',
#              ('el', 'l'): 'ell',
#              ('iv', 'e'): 'ive',
#              ('Ġ', 'ra'): 'Ġra',
#              ('a', 'w'): 'aw',
#              ('Ġ', 'ad'): 'Ġad',
#              ('at', 'ed'): 'ated',
#              ('Ġ', 'L'): 'ĠL',
#              ('oo', 'd'): 'ood',
#              ('en', 'd'): 'end',
#              ('or', 'm'): 'orm',
#              ('i', 'an'): 'ian',
#              ('on', 'g'): 'ong',
#              ('u', 'it'): 'uit',
#              ('Ġ', 'ri'): 'Ġri',
#              ('or', 'k'): 'ork',
#              ('on', 's'): 'ons',
#              ('am', 'p'): 'amp',
#              ('Ġg', 'r'): 'Ġgr',
#              ('e', 'f'): 'ef',
#              ('o', 'ot'): 'oot',
#              ('o', 'c'): 'oc',
#              ('i', 're'): 'ire',
#              ('el', 'y'): 'ely',
#              ('y', 's'): 'ys',
#              ('Ġh', 'and'): 'Ġhand',
#              ('Ġp', 'o'): 'Ġpo',
#              ('m', 'an'): 'man',
#              ('Ġc', 'ol'): 'Ġcol',
#              ('u', 'c'): 'uc',
#              ('m', 'ent'): 'ment',
#              ('Ġt', 'e'): 'Ġte',
#              ('Ġ', 'W'): 'ĠW',
#              ('et', 's'): 'ets',
#              ('Ġs', 'l'): 'Ġsl',
#              ('Ġc', 'ar'): 'Ġcar',
#              ('Ġb', 'ar'): 'Ġbar',
#              ('or', 'n'): 'orn',
#              ('i', 'b'): 'ib',
#              ('Ġ', 'E'): 'ĠE',
#              ('us', 'h'): 'ush',
#              ('at', 'ing'): 'ating',
#              ('Ġb', 'l'): 'Ġbl',
#              ('ow', 'n'): 'own',
#              ('Ġ', 'al'): 'Ġal',
#              ('w', 'ay'): 'way',
#              ('ic', 'al'): 'ical',
#              ('t', 'h'): 'th',
#              ('p', 'er'): 'per',
#              ('u', 'e'): 'ue',
#              ('g', 'e'): 'ge',
#              ('un', 'd'): 'und',
#              ('y', 'c'): 'yc',
#              ('e', 'p'): 'ep',
#              ('t', 'ain'): 'tain',
#              ('at', 'es'): 'ates',
#              ('Ġ', 'J'): 'ĠJ',
#              ('at', 'h'): 'ath',
#              ('Ġb', 'r'): 'Ġbr',
#              ('p', 'ed'): 'ped',
#              ('m', 'er'): 'mer',
#              ('Ġ', 'O'): 'ĠO',
#              ('v', 'e'): 've',
#              ('le', 't'): 'let',
#              ('b', 'er'): 'ber',
#              ('Ġp', 'ar'): 'Ġpar',
#              ('ch', 'es'): 'ches',
#              ('s', 'h'): 'sh',
#              ('n', 'ing'): 'ning',
#              ('i', 'k'): 'ik',
#              ('Ġc', 'r'): 'Ġcr',
#              ('i', 'al'): 'ial',
#              ('Ġ', 'N'): 'ĠN',
#              ('b', 's'): 'bs',
#              ('an', 'c'): 'anc',
#              ('Ġsn', 'ow'): 'Ġsnow',
#              ('at', 'er'): 'ater',
#              ('o', 'ck'): 'ock',
#              ('Ġp', 'r'): 'Ġpr',
#              ('in', 's'): 'ins',
#              ('Ġ', 'y'): 'Ġy',
#              ('o', 'ur'): 'our',
#              ('ul', 't'): 'ult',
#              ('p', 's'): 'ps',
#              ('el', 's'): 'els',
#              ('it', 'y'): 'ity',
#              ('ol', 'd'): 'old',
#              ('Ġt', 'ra'): 'Ġtra',
#              ('ug', 'h'): 'ugh',
#              ('ar', 'k'): 'ark',
#              ('f', 'ul'): 'ful',
#              ('ion', 's'): 'ions',
#              ('Ġ', 'ac'): 'Ġac',
#              ('in', 'd'): 'ind',
#              ('ak', 'e'): 'ake',
#              ('Ġ', 'ent'): 'Ġent',
#              ('Ġk', 'n'): 'Ġkn',
#              ('v', 'ers'): 'vers',
#              ('Ġcom', 'p'): 'Ġcomp',
#              ('Ġ', 'att'): 'Ġatt',
#              ('Ġ', 'app'): 'Ġapp',
#              ('ar', 'y'): 'ary',
#              ('Ġhe', 'ad'): 'Ġhead',
#              ('or', 'e'): 'ore',
#              ('Ġp', 'er'): 'Ġper',
#              ('es', 'c'): 'esc',
#              ('Ġ', 'K'): 'ĠK',
#              ('Ġ', 'V'): 'ĠV',
#              ('Ġm', 'an'): 'Ġman',
#              ('Ġw', 'h'): 'Ġwh',
#              ('Ġs', 'm'): 'Ġsm',
#              ('s', 'e'): 'se',
#              ('st', 'r'): 'str',
#              ('ic', 'e'): 'ice',
#              ('at', 'ch'): 'atch',
#              ('ac', 'e'): 'ace',
#              ('l', 'l'): 'll',
#              ('t', 'y'): 'ty',
#              ('Ġ', 'en'): 'Ġen',
#              ('ig', 'n'): 'ign',
#              ('p', 'l'): 'pl',
#              ('Ġo', 'ut'): 'Ġout',
#              ('p', 'h'): 'ph',
#              ('r', 'on'): 'ron',
#              ('Ġp', 'e'): 'Ġpe',
#              ('it', 's'): 'its',
#              ('ard', 's'): 'ards',
#              ('Ġb', 'o'): 'Ġbo',
#              ('e', 'v'): 'ev',
#              ('Ġs', 'o'): 'Ġso',
#              ('Ġd', 'is'): 'Ġdis',
#              ('r', 'ic'): 'ric',
#              ('i', 'er'): 'ier',
#              ('o', 'ol'): 'ool',
#              ('Ġ', 'I'): 'ĠI',
#              ('Ġre', 'c'): 'Ġrec',
#              ('er', 'v'): 'erv',
#              ('in', 'k'): 'ink',
#              ('al', 'k'): 'alk',
#              ('u', 'ck'): 'uck',
#              ('an', 'k'): 'ank',
#              ('ab', 'le'): 'able',
#              ('b', 'all'): 'ball',
#              ('oo', 'k'): 'ook',
#              ('Ġm', 'o'): 'Ġmo',
#              ('op', 's'): 'ops',
#              ('Ġin', 'ter'): 'Ġinter',
#              ('an', 'ce'): 'ance',
#              ('Ġw', 'e'): 'Ġwe',
#              ('ri', 'd'): 'rid',
#              ('un', 'g'): 'ung',
#              ('i', 'el'): 'iel',
#              ('Ġs', 'ur'): 'Ġsur',
#              ('e', 'y'): 'ey',
#              ('ing', 's'): 'ings',
#              ('t', 'e'): 'te',
#              ('ad', 'e'): 'ade',
#              ('al', 's'): 'als',
#              ('ar', 'm'): 'arm',
#              ('ec', 'k'): 'eck',
#              ('m', 'p'): 'mp',
#              ('at', 's'): 'ats',
#              ('Ġ', 'op'): 'Ġop',
#              ('Ġp', 're'): 'Ġpre',
#              ('l', 's'): 'ls',
#              ('Ġ', 'or'): 'Ġor',
#              ('ent', 's'): 'ents',
#              ('Ġb', 'ack'): 'Ġback',
#              ('ac', 'ks'): 'acks',
#              ('Ġo', 'ver'): 'Ġover',
#              ('a', 'f'): 'af',
#              ('ra', 'y'): 'ray',
#              ('ro', 'p'): 'rop',
#              ('s', 'p'): 'sp',
#              ('Ġcon', 't'): 'Ġcont',
#              ('an', 'n'): 'ann',
#              ('e', 'g'): 'eg',
#              ('Ġt', 'o'): 'Ġto',
#              ('Ġst', 'r'): 'Ġstr',
#              ('a', 'z'): 'az',
#              ('Ġd', 'o'): 'Ġdo',
#              ('ur', 'n'): 'urn',
#              ('Ġm', 'ot'): 'Ġmot',
#              ('re', 'ad'): 'read',
#              ('Ġc', 'lo'): 'Ġclo',
#              ('g', 'er'): 'ger',
#              ('ch', 'ing'): 'ching',
#              ('b', 'le'): 'ble',
#              ('Ġv', 'i'): 'Ġvi',
#              ('Ġ', 'qu'): 'Ġqu',
#              ('ist', 's'): 'ists',
#              ('it', 'e'): 'ite',
#              ('u', 'ff'): 'uff',
#              ('as', 'e'): 'ase',
#              ('l', 'er'): 'ler',
#              ('ar', 's'): 'ars',
#              ('um', 'p'): 'ump',
#              ('Ġc', 're'): 'Ġcre',
#              ('Ġt', 'ri'): 'Ġtri',
#              ('Ġm', 'e'): 'Ġme',
#              ('Ġc', 'ro'): 'Ġcro',
#              ('ar', 'e'): 'are',
#              ('c', 'o'): 'co',
#              ('or', 'd'): 'ord',
#              ('ad', 'd'): 'add',
#              ('Ġr', 'es'): 'Ġres',
#              ('Ġs', 'qu'): 'Ġsqu',
#              ('ra', 'w'): 'raw',
#              ('e', 'er'): 'eer',
#              ('s', 'c'): 'sc',
#              ('i', 'ous'): 'ious',
#              ('h', 'o'): 'ho',
#              ('Ġg', 'l'): 'Ġgl',
#              ('en', 'ce'): 'ence',
#              ('u', 'ct'): 'uct',
#              ('Ġre', 'f'): 'Ġref',
#              ('le', 'ct'): 'lect',
#              ('Ġm', 'ar'): 'Ġmar',
#              ('Ġf', 'lo'): 'Ġflo',
#              ('ug', 'g'): 'ugg',
#              ('ur', 'es'): 'ures',
#              ('Ġw', 'r'): 'Ġwr',
#              ('Ġd', 'ec'): 'Ġdec',
#              ('er', 'ed'): 'ered',
#              ('a', 'x'): 'ax',
#              ('ĠS', 't'): 'ĠSt',
#              ('i', 'le'): 'ile',
#              ('Ġst', 're'): 'Ġstre',
#              ('Ġ', 'am'): 'Ġam',
#              ('or', 'ed'): 'ored',
#              ('Ġs', 'up'): 'Ġsup',
#              ('v', 'el'): 'vel',
#              ('on', 'd'): 'ond',
#              ('em', 'ent'): 'ement',
#              ('Ġp', 'h'): 'Ġph',
#              ('f', 'orm'): 'form',
#              ('Ġ', 'ass'): 'Ġass',
#              ('Ġb', 're'): 'Ġbre',
#              ('Ġc', 'ur'): 'Ġcur',
#              ('at', 'or'): 'ator',
#              ('o', 'y'): 'oy',
#              ('o', 'k'): 'ok',
#              ('i', 'a'): 'ia',
#              ('ic', 's'): 'ics',
#              ('ch', 'ed'): 'ched',
#              ('Ġd', 'ri'): 'Ġdri',
#              ('er', 'y'): 'ery',
#              ('Ġs', 'un'): 'Ġsun',
#              ('om', 'e'): 'ome',
#              ('Ġd', 'r'): 'Ġdr',
#              ('b', 'y'): 'by',
#              ('v', 'en'): 'ven',
#              ('s', 's'): 'ss',
#              ('i', 'x'): 'ix',
#              ('in', 'es'): 'ines',
#              ('l', 'and'): 'land',
#              ('he', 'el'): 'heel',
#              ('ri', 's'): 'ris',
#              ('e', 'ed'): 'eed',
#              ('Ġre', 'p'): 'Ġrep',
#              ('ro', 'l'): 'rol',
#              ('b', 'r'): 'br',
#              ('Ġm', 'ed'): 'Ġmed',
#              ('Ġcon', 's'): 'Ġcons',
#              ('er', 'ing'): 'ering',
#              ('ee', 'p'): 'eep',
#              ('Ġp', 'at'): 'Ġpat',
#              ('Ġ', 'U'): 'ĠU',
#              ('i', 'ans'): 'ians',
#              ('Ġp', 'ol'): 'Ġpol',
#              ('Ġb', 'al'): 'Ġbal',
#              ('Ġ', 'as'): 'Ġas',
#              ('i', 'ke'): 'ike',
#              ('ur', 'ing'): 'uring',
#              ('Ġt', 'w'): 'Ġtw',
#              ('an', 'e'): 'ane',
#              ('Ġf', 'or'): 'Ġfor',
#              ('Ġ', 'up'): 'Ġup',
#              ('p', 't'): 'pt',
#              ('ul', 'l'): 'ull',
#              ('b', 'e'): 'be',
#              ('in', 'ing'): 'ining',
#              ('on', 'es'): 'ones',
#              ('ur', 's'): 'urs',
#              ('en', 'c'): 'enc',
#              ('Ġh', 'el'): 'Ġhel',
#              ('um', 'b'): 'umb',
#              ('ĠS', 'p'): 'ĠSp',
#              ('v', 'es'): 'ves',
#              ('ip', 's'): 'ips',
#              ('ĠC', 'h'): 'ĠCh',
#              ('om', 's'): 'oms',
#              ('Ġg', 'ra'): 'Ġgra',
#              ('m', 'ed'): 'med',
#              ('rap', 'h'): 'raph',
#              ('ir', 'l'): 'irl',
#              ('Ġin', 't'): 'Ġint',
#              ('ous', 'e'): 'ouse',
#              ('a', 'it'): 'ait',
#              ('ro', 'und'): 'round',
#              ('ap', 's'): 'aps',
#              ('f', 't'): 'ft',
#              ('Ġp', 'art'): 'Ġpart',
#              ('row', 'n'): 'rown',
#              ('ad', 'ing'): 'ading',
#              ('er', 't'): 'ert',
#              ('m', 'o'): 'mo',
#              ('Ġh', 'o'): 'Ġho',
#              ('g', 'ing'): 'ging',
#              ('en', 'ds'): 'ends',
#              ('ak', 'ing'): 'aking',
#              ('in', 't'): 'int',
#              ('is', 's'): 'iss',
#              ('Ġd', 'es'): 'Ġdes',
#              ('un', 'k'): 'unk',
#              ('Ġb', 'ut'): 'Ġbut',
#              ('iz', 'ed'): 'ized',
#              ('m', 'en'): 'men',
#              ('e', 'en'): 'een',
#              ('Ġ', 'im'): 'Ġim',
#              ('le', 'y'): 'ley',
#              ('it', 't'): 'itt',
#              ('ir', 't'): 'irt',
#              ('re', 'en'): 'reen',
#              ('Ġg', 'u'): 'Ġgu',
#              ('Ġb', 'ro'): 'Ġbro',
#              ('il', 'd'): 'ild',
#              ('an', 'ts'): 'ants',
#              ('Ġ', 'an'): 'Ġan',
#              ('ic', 'yc'): 'icyc',
#              ('ak', 'es'): 'akes',
#              ('d', 'o'): 'do',
#              ('Ġw', 'ater'): 'Ġwater',
#              ('al', 'e'): 'ale',
#              ('and', 's'): 'ands',
#              ('Ġsh', 'ow'): 'Ġshow',
#              ('Ġc', 'am'): 'Ġcam',
#              ('Ġg', 'o'): 'Ġgo',
#              ('Ġf', 'oot'): 'Ġfoot',
#              ('Ġb', 'as'): 'Ġbas',
#              ('it', 'ch'): 'itch',
#              ('Ġm', 'oun'): 'Ġmoun',
#              ('ill', 's'): 'ills',
#              ('Ġc', 'an'): 'Ġcan',
#              ('i', 'ff'): 'iff',
#              ('ic', 't'): 'ict',
#              ('ain', 't'): 'aint',
#              ('at', 'ers'): 'aters',
#              ('ation', 's'): 'ations',
#              ('Ġp', 'ass'): 'Ġpass',
#              ('c', 'ess'): 'cess',
#              ('Ġex', 'p'): 'Ġexp',
#              ('Ġc', 'ra'): 'Ġcra',
#              ('c', 'l'): 'cl',
#              ('Ġ', '1'): 'Ġ1',
#              ('is', 'e'): 'ise',
#              ('b', 'b'): 'bb',
#              ('r', 'ed'): 'red',
#              ('et', 'er'): 'eter',
#              ('c', 'om'): 'com',
#              ('Ġpl', 'ay'): 'Ġplay',
#              ('Ġ', 'on'): 'Ġon',
#              ('Ġc', 'le'): 'Ġcle',
#              ('p', 'ar'): 'par',
#              ('il', 'ing'): 'iling',
#              ('ir', 'c'): 'irc',
#              ('in', 'ed'): 'ined',
#              ('e', 'x'): 'ex',
#              ('Ġn', 'ew'): 'Ġnew',
#              ('Ġg', 'ro'): 'Ġgro',
#              ('Ġb', 'lo'): 'Ġblo',
#              ('y', 'm'): 'ym',
#              ('ak', 'er'): 'aker',
#              ('il', 'y'): 'ily',
#              ('at', 'her'): 'ather',
#              ('Ġsh', 'o'): 'Ġsho',
#              ('ing', 'er'): 'inger',
#              ('Ġf', 'r'): 'Ġfr',
#              ('Ġt', 're'): 'Ġtre',
#              ('Ġst', 'ri'): 'Ġstri',
#              ('g', 'h'): 'gh',
#              ('ot', 't'): 'ott',
#              ('Ġe', 'y'): 'Ġey',
#              ('Ġb', 'ur'): 'Ġbur',
#              ('un', 'n'): 'unn',
#              ('us', 's'): 'uss',
#              ('v', 'ent'): 'vent',
#              ('Ġmot', 'or'): 'Ġmotor',
#              ('Ġt', 'ro'): 'Ġtro',
#              ('Ġro', 'll'): 'Ġroll',
#              ('ud', 'd'): 'udd',
#              ('Ġ', 'z'): 'Ġz',
#              ('Ġc', 'ap'): 'Ġcap',
#              ('e', 'es'): 'ees',
#              ('he', 'ad'): 'head',
#              ('Ġd', 'ra'): 'Ġdra',
#              ('im', 'e'): 'ime',
#              ('u', 'al'): 'ual',
#              ('ar', 'n'): 'arn',
#              ('in', 'n'): 'inn',
#              ('a', 'us'): 'aus',
#              ('ast', 'er'): 'aster',
#              ('g', 'g'): 'gg',
#              ('ri', 'm'): 'rim',
#              ('Ġcon', 'd'): 'Ġcond',
#              ('Ġp', 'ed'): 'Ġped',
#              ('i', 'o'): 'io',
#              ('os', 's'): 'oss',
#              ('ad', 'er'): 'ader',
#              ('Ġd', 'own'): 'Ġdown',
#              ('i', 'ed'): 'ied',
#              ('Ġ', 'el'): 'Ġel',
#              ('Ġo', 'ff'): 'Ġoff',
#              ('l', 'ers'): 'lers',
#              ('am', 'e'): 'ame',
#              ('oun', 'd'): 'ound',
#              ('id', 's'): 'ids',
#              ('or', 'ts'): 'orts',
#              ('w', 'ork'): 'work',
#              ('en', 'ding'): 'ending',
#              ('p', 'e'): 'pe',
#              ('Ġt', 'ow'): 'Ġtow',
#              ('el', 'ling'): 'elling',
#              ('I', 'n'): 'In',
#              ('out', 'h'): 'outh',
#              ('iel', 'd'): 'ield',
#              ('Ġh', 'air'): 'Ġhair',
#              ('Ġb', 'ow'): 'Ġbow',
#              ('u', 'ch'): 'uch',
#              ('Ġs', 'le'): 'Ġsle',
#              ('Ġs', 'ec'): 'Ġsec',
#              ('Ġl', 'a'): 'Ġla',
#              ('ail', 's'): 'ails',
#              ('ip', 'ping'): 'ipping',
#              ('uc', 'ks'): 'ucks',
#              ('Ġcol', 'l'): 'Ġcoll',
#              ('Ġco', 'un'): 'Ġcoun',
#              ('r', 'ing'): 'ring',
#              ('i', 'qu'): 'iqu',
#              ('m', 'ing'): 'ming',
#              ('Ġa', 'w'): 'Ġaw',
#              ('ri', 'st'): 'rist',
#              ('Ġpr', 'es'): 'Ġpres',
#              ('Ġre', 't'): 'Ġret',
#              ('Ġtr', 'ans'): 'Ġtrans',
#              ('Ġ', 'ag'): 'Ġag',
#              ('Ġm', 'on'): 'Ġmon',
#              ('ul', 'ar'): 'ular',
#              ('er', 'man'): 'erman',
#              ('Ġt', 'ur'): 'Ġtur',
#              ('Ġw', 'in'): 'Ġwin',
#              ('Ġ', 'Y'): 'ĠY',
#              ('Ġre', 'l'): 'Ġrel',
#              ('y', 'l'): 'yl',
#              ('id', 'es'): 'ides',
#              ('st', 'er'): 'ster',
#              ('g', 'an'): 'gan',
#              ('Ġh', 'um'): 'Ġhum',
#              ('ter', 'n'): 'tern',
#              ('ical', 'ly'): 'ically',
#              ('og', 'raph'): 'ograph',
#              ('p', 'p'): 'pp',
#              ('b', 'l'): 'bl',
#              ('Ġ', '2'): 'Ġ2',
#              ('s', 'ide'): 'side',
#              ('it', 'h'): 'ith',
#              ('ang', 'e'): 'ange',
#              ('ay', 's'): 'ays',
#              ('Ġb', 'us'): 'Ġbus',
#              ('y', 'ing'): 'ying',
#              ('it', 'ion'): 'ition',
#              ('Ġp', 'ast'): 'Ġpast',
#              ('Ġ', 'ab'): 'Ġab',
#              ('Ġb', 'u'): 'Ġbu',
#              ('ic', 'ks'): 'icks',
#              ('low', 'ing'): 'lowing',
#              ('Ġl', 'ab'): 'Ġlab',
#              ('e', 'a'): 'ea',
#              ('Ġs', 'ol'): 'Ġsol',
#              ('Ġin', 'f'): 'Ġinf',
#              ('Ġin', 'd'): 'Ġind',
#              ('Ġm', 'et'): 'Ġmet',
#              ('Ġcom', 'm'): 'Ġcomm',
#              ('Ġsw', 'eat'): 'Ġsweat',
#              ('Ġf', 'ire'): 'Ġfire',
#              ('her', 'e'): 'here',
#              ('c', 'ks'): 'cks',
#              ('ac', 'es'): 'aces',
#              ('Ġre', 'g'): 'Ġreg',
#              ('Ġf', 'ol'): 'Ġfol',
#              ('Ġw', 'heel'): 'Ġwheel',
#              ('ic', 'an'): 'ican',
#              ('Ġb', 'ag'): 'Ġbag',
#              ('Ġsur', 'f'): 'Ġsurf',
#              ('air', 's'): 'airs',
#              ('el', 'ing'): 'eling',
#              ('en', 'g'): 'eng',
#              ('le', 'c'): 'lec',
#              ('igh', 'ts'): 'ights',
#              ('Ġpro', 't'): 'Ġprot',
#              ('ĠM', 'ar'): 'ĠMar',
#              ('am', 's'): 'ams',
#              ('o', 'on'): 'oon',
#              ('ag', 'es'): 'ages',
#              ('ish', 'ed'): 'ished',
#              ('u', 'es'): 'ues',
#              ('Ġm', 'in'): 'Ġmin',
#              ('Ġsp', 'l'): 'Ġspl',
#              ('e', 'b'): 'eb',
#              ('ut', 'e'): 'ute',
#              ('g', 'es'): 'ges',
#              ('ug', 's'): 'ugs',
#              ('iv', 'ely'): 'ively',
#              ('z', 'z'): 'zz',
#              ('al', 'ly'): 'ally',
#              ('p', 'an'): 'pan',
#              ('Ġe', 'm'): 'Ġem',
#              ('Ġd', 'ef'): 'Ġdef',
#              ('al', 'es'): 'ales',
#              ('Ġcl', 'im'): 'Ġclim',
#              ('Ġo', 'bs'): 'Ġobs',
#              ('id', 'd'): 'idd',
#              ('re', 'e'): 'ree',
#              ('v', 'ing'): 'ving',
#              ('Ġp', 'ow'): 'Ġpow',
#              ('Ġin', 'str'): 'Ġinstr',
#              ('Ġm', 'us'): 'Ġmus',
#              ('r', 'en'): 'ren',
#              ('Ġs', 'and'): 'Ġsand',
#              ('Ġs', 'om'): 'Ġsom',
#              ('et', 'h'): 'eth',
#              ('av', 'ing'): 'aving',
#              ('ir', 'ts'): 'irts',
#              ('Ġs', 'il'): 'Ġsil',
#              ('Ġb', 'all'): 'Ġball',
#              ('l', 'ass'): 'lass',
#              ('ut', 's'): 'uts',
#              ('n', 'ic'): 'nic',
#              ('Ġo', 'b'): 'Ġob',
#              ('est', 'ing'): 'esting',
#              ('est', 'ed'): 'ested',
#              ('Ġw', 'ar'): 'Ġwar',
#              ('ac', 'ing'): 'acing',
#              ('gh', 't'): 'ght',
#              ('board', 'er'): 'boarder',
#              ('Ġst', 'e'): 'Ġste',
#              ('Ġb', 'at'): 'Ġbat',
#              ('Ġex', 't'): 'Ġext',
#              ('Ġsw', 'im'): 'Ġswim',
#              ('Ġa', 'f'): 'Ġaf',
#              ('Ġa', 'ir'): 'Ġair',
#              ('Ġl', 'and'): 'Ġland',
#              ('a', 'ff'): 'aff',
#              ('Ġf', 'eat'): 'Ġfeat',
#              ('ect', 'ion'): 'ection',
#              ('Ġen', 'g'): 'Ġeng',
#              ('Ġ', 'ant'): 'Ġant',
#              ('ist', 'er'): 'ister',
#              ('Ġb', 'ath'): 'Ġbath',
#              ('Ġe', 'le'): 'Ġele',
#              ('yc', 'l'): 'ycl',
#              ('ach', 'es'): 'aches',
#              ('en', 'n'): 'enn',
#              ('Ġc', 'amp'): 'Ġcamp',
#              ('st', 'and'): 'stand',
#              ('et', 'te'): 'ette',
#              ('Ġc', 'e'): 'Ġce',
#              ('Ġph', 'ot'): 'Ġphot',
#              ('Ġg', 'ar'): 'Ġgar',
#              ('ell', 's'): 'ells',
#              ('Ġl', 'if'): 'Ġlif',
#              ('ol', 'l'): 'oll',
#              ('Ġf', 'le'): 'Ġfle',
#              ('Ġp', 'ot'): 'Ġpot',
#              ('uit', 's'): 'uits',
#              ('Ġ', 'act'): 'Ġact',
#              ('ad', 's'): 'ads',
#              ('at', 'ure'): 'ature',
#              ('ag', 'ed'): 'aged',
#              ('g', 'y'): 'gy',
#              ('Ġv', 'is'): 'Ġvis',
#              ('Ġd', 'em'): 'Ġdem',
#              ('iv', 'es'): 'ives',
#              ('id', 'ent'): 'ident',
#              ('t', 'op'): 'top',
#              ('op', 'e'): 'ope',
#              ('v', 'i'): 'vi',
#              ('Ġin', 'sp'): 'Ġinsp',
#              ('ur', 'ed'): 'ured',
#              ('iz', 'e'): 'ize',
#              ('in', 'er'): 'iner',
#              ('board', 's'): 'boards',
#              ('d', 'y'): 'dy',
#              ('ress', 'es'): 'resses',
#              ('ow', 's'): 'ows',
#              ('f', 'er'): 'fer',
#              ('it', 'ing'): 'iting',
#              ('Ġre', 'm'): 'Ġrem',
#              ('al', 'm'): 'alm',
#              ('in', 'a'): 'ina',
#              ('Ġc', 'or'): 'Ġcor',
#              ('Ġb', 'oun'): 'Ġboun',
#              ('ib', 'le'): 'ible',
#              ('c', 'c'): 'cc',
#              ('ful', 'ly'): 'fully',
#              ('at', 'ely'): 'ately',
#              ('f', 's'): 'fs',
#              ('id', 'er'): 'ider',
#              ('o', 'st'): 'ost',
#              ('if', 'ic'): 'ific',
#              ('r', 'it'): 'rit',
#              ('ant', 'ly'): 'antly',
#              ('h', 'ouse'): 'house',
#              ('Ġw', 'ind'): 'Ġwind',
#              ('Ġ', 'at'): 'Ġat',
#              ('Ġh', 'ol'): 'Ġhol',
#              ('Ġh', 'er'): 'Ġher',
#              ('ph', 'one'): 'phone',
#              ('id', 'ing'): 'iding',
#              ('ear', 'ing'): 'earing',
#              ('Ġsp', 'r'): 'Ġspr',
#              ('ay', 'ing'): 'aying',
#              ('o', 'king'): 'oking',
#              ('Ġp', 'ack'): 'Ġpack',
#              ('ir', 'd'): 'ird',
#              ('Ġbar', 'b'): 'Ġbarb',
#              ('Ġar', 'm'): 'Ġarm',
#              ('ic', 'king'): 'icking',
#              ('Ġcomp', 'et'): 'Ġcompet',
#              ('all', 's'): 'alls',
#              ('d', 'og'): 'dog',
#              ('Ġ', 'art'): 'Ġart',
#              ('p', 'le'): 'ple',
#              ('Ġc', 'art'): 'Ġcart',
#              ('oot', 'h'): 'ooth',
#              ('Ġst', 'ro'): 'Ġstro',
#              ('Ġf', 'ish'): 'Ġfish',
#              ('Ġd', 'ire'): 'Ġdire',
#              ('av', 'e'): 'ave',
#              ('Ġs', 'ub'): 'Ġsub',
#              ('Ġt', 'ub'): 'Ġtub',
#              ('ent', 'ly'): 'ently',
#              ('Ġb', 'ri'): 'Ġbri',
#              ('Ġp', 'ig'): 'Ġpig',
#              ('Ġw', 'ork'): 'Ġwork',
#              ('l', 'ess'): 'less',
#              ('Ġsc', 'r'): 'Ġscr',
#              ('Ġv', 'ol'): 'Ġvol',
#              ('em', 'b'): 'emb',
#              ('ra', 'm'): 'ram',
#              ('Ġp', 'an'): 'Ġpan',
#              ('ach', 'ed'): 'ached',
#              ('S', 'k'): 'Sk',
#              ('o', 'op'): 'oop',
#              ('p', 'ers'): 'pers',
#              ('ri', 'es'): 'ries',
#              ('v', 'ed'): 'ved',
#              ('Ġh', 'am'): 'Ġham',
#              ('ud', 'e'): 'ude',
#              ('Ġh', 'ur'): 'Ġhur',
#              ('Ġent', 'er'): 'Ġenter',
#              ('Ġs', 'lo'): 'Ġslo',
#              ('Ġdec', 'or'): 'Ġdecor',
#              ('Ġch', 'eer'): 'Ġcheer',
#              ('d', 'ers'): 'ders',
#              ('e', 'ad'): 'ead',
#              ('i', 'um'): 'ium',
#              ('on', 'str'): 'onstr',
#              ('Ġe', 'ar'): 'Ġear',
#              ('ugh', 't'): 'ught',
#              ('en', 'ing'): 'ening',
#              ('Ġvi', 'ew'): 'Ġview',
#              ('at', 'ors'): 'ators',
#              ('es', 'e'): 'ese',
#              ('anc', 'es'): 'ances',
#              ('as', 'k'): 'ask',
#              ('ear', 's'): 'ears',
#              ('Ġf', 'il'): 'Ġfil',
#              ('Ġar', 'r'): 'Ġarr',
#              ('Ġf', 'orm'): 'Ġform',
#              ('Ġ', 'ang'): 'Ġang',
#              ('ic', 'ip'): 'icip',
#              ('c', 'on'): 'con',
#              ('Ġex', 'c'): 'Ġexc',
#              ('it', 'ed'): 'ited',
#              ('ir', 'ed'): 'ired',
#              ('ef', 'ul'): 'eful',
#              ('h', 'am'): 'ham',
#              ('Ġg', 're'): 'Ġgre',
#              ('Ġt', 'er'): 'Ġter',
#              ('n', 'g'): 'ng',
#              ('Ġb', 'and'): 'Ġband',
#              ('in', 'o'): 'ino',
#              ('S', 't'): 'St',
#              ('am', 'a'): 'ama',
#              ('l', 'if'): 'lif',
#              ('Ġar', 'ch'): 'Ġarch',
#              ('il', 's'): 'ils',
#              ('Ġor', 'gan'): 'Ġorgan',
#              ('l', 'ight'): 'light',
#              ('w', 'ard'): 'ward',
#              ('i', 'or'): 'ior',
#              ('Ġd', 'el'): 'Ġdel',
#              ('on', 'ed'): 'oned',
#              ('Ġf', 'in'): 'Ġfin',
#              ('Ġd', 'i'): 'Ġdi',
#              ('r', 'es'): 'res',
#              ('0', '0'): '00',
#              ('lo', 'ck'): 'lock',
#              ('ĠS', 'h'): 'ĠSh',
#              ('oun', 'g'): 'oung',
#              ('Ġop', 'er'): 'Ġoper',
#              ('Ġp', 'ul'): 'Ġpul',
#              ('b', 'ing'): 'bing',
#              ('Ġn', 'ot'): 'Ġnot',
#              ('ron', 't'): 'ront',
#              ('Ġp', 'ain'): 'Ġpain',
#              ('ic', 'h'): 'ich',
#              ('Ġc', 'irc'): 'Ġcirc',
#              ('Ġs', 'id'): 'Ġsid',
#              ('g', 'round'): 'ground',
#              ('o', 'u'): 'ou',
#              ('Ġ', 'i'): 'Ġi',
#              ('Ġc', 'up'): 'Ġcup',
#              ('Ġm', 'ult'): 'Ġmult',
#              ('or', 'y'): 'ory',
#              ('Ġw', 'alk'): 'Ġwalk',
#              ('rid', 'e'): 'ride',
#              ('a', 'e'): 'ae',
#              ('ry', 'ing'): 'rying',
#              ('i', 'ec'): 'iec',
#              ('ap', 'er'): 'aper',
#              ('Ġro', 'ck'): 'Ġrock',
#              ('Ġb', 'el'): 'Ġbel',
#              ('os', 'e'): 'ose',
#              ('Ġr', 'est'): 'Ġrest',
#              ('Ġtra', 'vel'): 'Ġtravel',
#              ('T', 'h'): 'Th',
#              ('re', 'g'): 'reg',
#              ('Ġcon', 'c'): 'Ġconc',
#              ('Ġsk', 'ate'): 'Ġskate',
#              ('ain', 's'): 'ains',
#              ('Ġcro', 'ss'): 'Ġcross',
#              ('Ġ', '3'): 'Ġ3',
#              ('Ġout', 'f'): 'Ġoutf',
#              ('b', 'ed'): 'bed',
#              ('ash', 'ing'): 'ashing',
#              ('Ġp', 'add'): 'Ġpadd',
#              ('Ġres', 'p'): 'Ġresp',
#              ('Ġmoun', 'tain'): 'Ġmountain',
#              ('Ġper', 'form'): 'Ġperform',
#              ('as', 'es'): 'ases',
#              ('ke', 'y'): 'key',
#              ('Ġb', 'ik'): 'Ġbik',
#              ('g', 'ers'): 'gers',
#              ('Ġh', 'ors'): 'Ġhors',
#              ('Ġst', 'ar'): 'Ġstar',
#              ('c', 'ar'): 'car',
#              ('ash', 'es'): 'ashes',
#              ('Ġa', 'ut'): 'Ġaut',
#              ('Ġp', 'on'): 'Ġpon',
#              ('Ġ', 'us'): 'Ġus',
#              ('Ġd', 'raw'): 'Ġdraw',
#              ('Ġk', 'ick'): 'Ġkick',
#              ('Ġf', 'arm'): 'Ġfarm',
#              ('Ġf', 'low'): 'Ġflow',
#              ('Ġro', 'w'): 'Ġrow',
#              ('Ġbre', 'ak'): 'Ġbreak',
#              ('ash', 'ion'): 'ashion',
#              ('ed', 's'): 'eds',
#              ('um', 'ber'): 'umber',
#              ('Ġc', 'ut'): 'Ġcut',
#              ('Ġs', 'ign'): 'Ġsign',
#              ('um', 'e'): 'ume',
#              ('Ġch', 'eck'): 'Ġcheck',
#              ('Ġf', 're'): 'Ġfre',
#              ('u', 'ro'): 'uro',
#              ('g', 's'): 'gs',
#              ('oo', 'ks'): 'ooks',
#              ('it', 'al'): 'ital',
#              ('C', 'h'): 'Ch',
#              ('Ġm', 'ess'): 'Ġmess',
#              ('ot', 's'): 'ots',
#              ('lo', 'y'): 'loy',
#              ('op', 'ping'): 'opping',
#              ('oo', 'ds'): 'oods',
#              ('Ġdr', 'um'): 'Ġdrum',
#              ('Ġs', 'erv'): 'Ġserv',
#              ('Ġm', 'a'): 'Ġma',
#              ('Ġd', 'ist'): 'Ġdist',
#              ('ment', 's'): 'ments',
#              ('h', 'aw'): 'haw',
#              ('Ġd', 'iv'): 'Ġdiv',
#              ('vi', 'ew'): 'view',
#              ('Ġc', 'ab'): 'Ġcab',
#              ('Ġg', 'lo'): 'Ġglo',
#              ...})

# %%
len(merges)
# Out:
# 9918

# %%
def tokenize(text):
    tokenize_result = tokenizer.backend_tokenizer.pre_tokenizer.pre_tokenize_str(text)
    tokenized_text = [word for word, offset in tokenize_result]
    splits = [[c for c in word] for word in tokenized_text]
    for pair, merge in merges.items():
        for idx, split in enumerate(splits):
            i = 0
            while i < len(split)-1:
                if split[i] == pair[0] and split[i+1] == pair[1]:
                    split = split[:i] + [merge] + split[i+2:]
                else:
                    i += 1
            splits[idx] = split
    return sum(splits, [])

tokenize("This is not a token ϶.")
# Out:
# ['This', 'Ġis', 'Ġnot', 'Ġa', 'Ġto', 'ken', 'Ġ', 'Ï', '¶', '.']
